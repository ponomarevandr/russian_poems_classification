# %%
import numpy as np
import pandas as pd
import re
import tqdm
import matplotlib.pyplot as plt

import os
from pathlib import Path
import gensim.downloader
import pymorphy3

# %%
df_poems = pd.read_csv('../data/poems_dataset.csv')
df_poems
# Out:
#          author       epoch                         title  part  \
# 0      Агнивцев   символизм                  брат антонио     0
# 1      Агнивцев   символизм                 грузовик 1317     0
# 2      Агнивцев   символизм                 грузовик 1317     1
# 3      Агнивцев   символизм                  мэри пикфорд     0
# 4      Агнивцев   символизм                      бильбокэ     0
# ...         ...         ...                           ...   ...
# 54232      Яшин  соцреализм                     зеркальце     2
# 54233      Яшин  соцреализм  очень много солнечного света     0
# 54234      Яшин  соцреализм                        огонек     0
# 54235      Яшин  соцреализм    назови меня именем светлым     0
# 54236      Яшин  соцреализм                   твоя родина     0
#
#                                                     text
# 0      В монастырской тихой келье,\nПозабывши о весел...
# 1      Весь машинный свой век, каждый день по утрам\n...
# 2      Грузовик № 1317.\nНо открылись фронты! О, услы...
# 3      В Америке где-то\nСудя по газетам,\nЕсть город...
# 4      К дофину Франции, в печали,\nСкользнув тайком,...
# ...                                                  ...
# 54232  В руки зеркальце взяла\nИ сказала:\n«Удружи,\n...
# 54233  Очень много солнечного света,\nНад землей стои...
# 54234  Светлячок во мгле —\nОгонек в лесах.\nМожет, о...
# 54235  Назови меня именем светлым,\nЧистым именем наз...
# 54236  Все испытала, все превозмогла —\nГода тяжелых ...
#
# [54237 rows x 5 columns]

# %%
stopwords = nltk.corpus.stopwords.words('russian')
# print(stopwords)

# %%
os.environ['GENSIM_DATA_DIR'] = str(Path.cwd())
gensim_embeddings = gensim.downloader.load('word2vec-ruscorpora-300')
gensim_words = np.array([
    element.split('_') for element in gensim_embeddings.index_to_key
])
np.unique(gensim_words[:, 1])
# Out:
# array(['ADJ', 'ADP', 'ADV', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART',
#        'PRON', 'VERB'], dtype='<U49')

# %%
morph = pymorphy3.MorphAnalyzer()
tags_to_transform = {
    'ADJF': 'ADJ',
    'ADJS': 'ADJ',
    'COMP': 'ADJ',
    'INFN': 'VERB',
    'PRTF': 'VERB',
    'PRTS': 'VERB',
    'GRND': 'VERB',
    'NUMR': 'NUM',
    'ADVB': 'ADV',
    'PREP': 'ADP',
    'NPRO': 'PRON',
    'PRCL': 'PART',
    'CONJ': 'CCONJ',
}

def morph_parse(word):
    normal_form = morph.parse(word)[0].normal_form
    normal_form = re.sub('ё', 'е', normal_form)
    part_tag = re.findall(r'\w+', str(morph.parse(word)[0].tag))[0]
    if part_tag in tags_to_transform:
        part_tag = tags_to_transform[part_tag]
    return normal_form + '_' + part_tag

def get_embedding_tagged(tagged):
    if tagged in gensim_embeddings:
        return True, gensim_embeddings[tagged]
    else:
        return False, np.zeros(300)

def get_embedding(word):
    tagged = morph_parse(word)
    return get_embedding_tagged(tagged)

# %%
(get_embedding('стол')[1] * get_embedding('стул')[1]).sum()
# Out:
# 0.70359695

# %%
class WordsEncoder:
    def __init__(self):
        self._vocab = dict()
        self._vocab_occurances = dict()
        self._no_embedding_occurances = dict()

    def split(text):
        return re.findall(r'[а-яё]+', text.lower())
    
    def add_to_vocab(self, texts):
        for text in tqdm.tqdm(texts):
            for word in WordsEncoder.split(text):
                tagged = morph_parse(word)
                if tagged in self._vocab_occurances:
                    self._vocab_occurances[tagged] += 1
                    continue
                if tagged in self._no_embedding_occurances:
                    self._no_embedding_occurances[tagged] += 1
                    continue
                if get_embedding_tagged(tagged)[0]:
                    self._vocab[tagged] = len(self._vocab)
                    self._vocab_occurances[tagged] = 1
                else:
                    self._no_embedding_occurances[tagged] = 1
    
    def info(self):
        words_vocab = len(self._vocab)
        words_total = words_vocab + len(self._no_embedding_occurances)
        print('Processed unique words:', words_total)
        print('Of them with embeddings:', words_vocab, '({:.2f} %)'.format(
            words_vocab / words_total * 100.0
        ))
        self.vocab_occurances_list = pd.DataFrame(
            list(self._vocab_occurances.items()),
            columns=['word', 'occurances']
        )
        self.vocab_occurances_list.sort_values('occurances', ascending=False, inplace=True)
        self.no_embedding_occurances_list = pd.DataFrame(
            list(self._no_embedding_occurances.items()),
            columns=['word', 'occurances']
        )
        self.no_embedding_occurances_list.sort_values('occurances', ascending=False, inplace=True)
        occurances_vocab = self.vocab_occurances_list['occurances'].sum()
        occurances_total = occurances_vocab + self.no_embedding_occurances_list['occurances'].sum()
        print('Processed word occurances:', occurances_total)
        print('Of them with embeddings:', occurances_vocab, '({:.2f} %)'.format(
            occurances_vocab / occurances_total * 100.0
        ))
    
    def to_embeddings(self, text):
        embeddings = []
        for word in WordsEncoder.split(text):
            tagged = morph_parse(word)
            if tagged in self._vocab:
                embeddings.append(get_embedding_tagged(tagged)[1])
        return np.array(embeddings)

# %%
words_encoder = WordsEncoder()
words_encoder.add_to_vocab(df_poems['text'][:1000])
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:11<00:00, 88.27it/s]

# %%
words_encoder.info()
# Out:
# Processed unique words: 10561
# Of them with embeddings: 8514 (80.62 %)
# Processed word occurances: 89165
# Of them with embeddings: 46232 (51.85 %)

# %%
words_encoder.to_embeddings('человек собаке друг')
# Out:
# array([[-1.39451608e-01,  9.53103136e-03,  9.66905281e-02,
#         -5.21333963e-02, -3.12726162e-02,  5.05528040e-02,
#         -2.52584498e-02,  1.03141125e-02,  6.70733973e-02,
#         -5.00828680e-03,  5.17660528e-02, -7.06560239e-02,
#         -9.39404890e-02,  3.94431055e-02, -1.94523740e-03,
#          6.24135835e-03,  3.44324149e-02, -6.78158645e-03,
#          9.03536752e-02, -8.52523595e-02,  6.77594543e-03,
#          7.92675912e-02, -4.68349978e-02,  1.66406110e-01,
#          5.13189882e-02, -1.28330097e-01,  4.83062007e-02,
#         -1.24150440e-02,  6.14518113e-02,  5.94375022e-02,
#          3.58966626e-02,  4.60047200e-02,  9.96816829e-02,
#         -2.71439832e-02, -8.44711140e-02,  1.57809872e-02,
#          6.06710054e-02,  9.07780081e-02, -2.32378375e-02,
#          1.06120734e-02, -2.46277750e-02,  1.51019944e-02,
#         -2.39656940e-02,  4.68896236e-03, -1.91762242e-02,
#          7.07543492e-02,  6.47879764e-02,  5.65436482e-03,
#          8.41793343e-02, -8.19936395e-02,  5.08622378e-02,
#          7.64556080e-02,  3.26187164e-02,  5.04927598e-02,
#          8.35295767e-02, -1.90955848e-02, -1.47118852e-01,
#          2.50411201e-02,  5.59807057e-03, -3.68955657e-02,
#         -6.40969574e-02, -8.85586487e-04,  7.75761455e-02,
#         -1.04955351e-02,  1.96027793e-02,  2.42743827e-02,
#         -5.85046783e-02,  2.06608744e-03,  3.39085385e-02,
#          7.80592859e-02,  1.02183670e-02,  2.05113217e-02,
#          4.23536114e-02, -9.90806818e-02, -6.45209523e-03,
#          1.35650896e-02, -4.38244315e-03,  1.96329653e-02,
#          5.42883761e-02, -3.31401378e-02, -4.05219942e-02,
#          8.04363862e-02, -1.99389495e-02, -7.28101134e-02,
#          1.53917251e-02, -2.79782321e-02, -9.65910852e-02,
#          3.84446383e-02, -8.35733637e-02, -4.83663715e-02,
#         -5.32946438e-02, -7.90803060e-02,  3.92592922e-02,
#          6.50598556e-02,  7.17095658e-03,  4.72197123e-02,
#         -1.89574677e-02, -5.29370345e-02,  1.11345118e-02,
#         -1.59570873e-02, -6.47481605e-02, -4.14119773e-02,
#         -1.48561401e-02, -3.74819674e-02,  3.30101745e-03,
#         -3.52856293e-02,  2.29258146e-02, -7.32129514e-02,
#          2.37879474e-02, -1.52801508e-02, -4.72415611e-03,
#         -2.37037800e-02,  1.93777159e-02,  4.41521853e-02,
#         -3.09873205e-02,  1.26693603e-02,  9.48226526e-02,
#          2.73855217e-02,  1.83234215e-02, -3.60973808e-03,
#          5.15030585e-02, -6.27320856e-02, -1.63039248e-02,
#          1.07397996e-02, -5.16666472e-02,  1.74234658e-02,
#         -4.03397977e-02,  4.84551489e-02, -9.86768156e-02,
#          4.65736724e-02, -7.46139809e-02, -2.69072969e-02,
#         -1.44226151e-03,  1.50484309e-01,  2.79697450e-03,
#         -2.65995469e-02, -6.09510094e-02,  6.26805350e-02,
#          4.48322222e-02, -5.18178148e-03,  2.93713100e-02,
#         -3.87411118e-02, -5.95339052e-02, -6.78999797e-02,
#          3.50683108e-02, -1.80428252e-02, -1.30320946e-02,
#         -5.31028882e-02, -2.33974634e-03,  2.96204854e-02,
#         -1.39939496e-02,  1.00354791e-01, -5.59427142e-02,
#          5.14485948e-02, -7.37592131e-02,  5.67741692e-02,
#          1.03283336e-03,  6.55681267e-02, -2.34853067e-02,
#          1.93005893e-02, -7.01027885e-02,  3.19007710e-02,
#         -5.38172238e-02,  3.53346914e-02, -8.07421468e-03,
#         -1.35002747e-01, -1.49520915e-02,  1.39781050e-02,
#         -1.97196171e-01, -2.91908998e-02,  1.32527158e-01,
#         -4.82204072e-02,  3.88724022e-02,  3.40678506e-02,
#          5.14731556e-02,  7.66034797e-02, -1.11916093e-02,
#          5.29076532e-02,  4.80381772e-02, -8.68567154e-02,
#         -9.63755604e-03,  7.99716339e-02,  2.42386525e-03,
#          1.18441032e-02,  9.50114150e-03, -5.34864441e-02,
#          5.69108352e-02, -3.36996168e-02,  4.67643701e-02,
#         -7.10533559e-02, -3.53888348e-02, -1.13479532e-01,
#          4.81161773e-02,  5.64839691e-02,  8.55833143e-02,
#         -2.53555574e-03,  3.75490673e-02,  6.41150679e-03,
#          1.57022867e-02, -3.03517524e-02,  1.01936832e-02,
#         -1.75819378e-02, -8.70994329e-02, -2.44943891e-02,
#         -6.81143403e-02, -2.94914115e-02, -4.42852490e-02,
#         -1.49818892e-02,  2.52525788e-02,  6.15523104e-03,
#         -3.86004336e-02,  1.86481923e-02, -1.96158849e-02,
#          2.58912239e-02,  7.81097636e-02, -2.41755098e-02,
#          3.23123634e-02,  5.72369061e-02, -7.10199252e-02,
#          1.17622539e-01, -2.35384889e-03, -4.00627218e-02,
#         -3.96703780e-02,  6.57590330e-02,  2.85115074e-02,
#          6.15953468e-03, -9.10856351e-02,  4.76057343e-02,
#         -1.59837771e-02, -2.68120435e-03, -2.12116372e-02,
#         -8.57867524e-02, -1.65586844e-02,  8.46391022e-02,
#         -1.69697046e-01, -6.53515160e-02,  3.35321538e-02,
#          5.35962358e-02, -7.38840997e-02, -3.52460258e-02,
#          6.18084334e-02,  3.59853320e-02, -9.57785267e-03,
#          2.89396383e-02,  4.97692963e-03,  8.49829018e-02,
#          1.20281637e-01, -9.18065012e-02, -6.49550632e-02,
#          2.34019067e-02, -2.72445790e-02, -1.62802324e-01,
#          9.08246636e-02,  1.38153508e-01,  8.21512714e-02,
#         -3.96847874e-02,  2.56484300e-02,  1.15191936e-02,
#          5.17879538e-02,  6.27708361e-02, -2.80771051e-02,
#          1.52709922e-02, -3.71481217e-02, -4.45801243e-02,
#         -2.81162802e-02, -1.10586034e-02, -2.50323713e-02,
#         -9.47771873e-03, -4.80100177e-02, -4.48540449e-02,
#         -2.42652781e-02, -2.68851854e-02, -4.26715566e-03,
#          3.10148560e-02,  1.86462384e-02, -6.35797381e-02,
#          9.65217128e-02, -5.22877381e-04, -2.91228611e-02,
#         -9.02569853e-03, -1.09228961e-01,  3.89566682e-02,
#          1.12588041e-01, -1.61041971e-02,  3.49181890e-02,
#         -3.38670723e-02, -1.44983202e-01, -8.46079290e-02,
#         -1.27190212e-02,  4.87003699e-02, -1.41664250e-02,
#         -4.74760681e-02, -5.58989793e-02,  3.77907529e-02,
#         -3.58889848e-02, -3.46288607e-02,  2.44455673e-02,
#          1.36064544e-01, -1.11053279e-02,  7.05856681e-02],
#        [-3.38884294e-02, -7.81310815e-03,  2.11370923e-03,
#         -2.92390138e-02,  9.66224298e-02, -6.50296733e-02,
#          2.40253936e-02, -1.79325100e-02,  2.77531222e-02,
#         -8.89075473e-02,  1.98206846e-02, -5.74715249e-02,
#          4.46872897e-02,  3.24852020e-02, -9.21151601e-03,
#         -6.71269521e-02,  8.43230933e-02, -4.01344299e-02,
#          8.19142461e-02, -6.77698925e-02,  9.38561112e-02,
#          5.17033748e-02,  7.83202499e-02,  8.44776183e-02,
#         -9.80200712e-04, -9.22067463e-02,  1.64643098e-02,
#          7.69851804e-02,  1.24629121e-02,  2.01467928e-02,
#         -7.68297538e-02,  3.69389914e-02,  4.97399792e-02,
#         -7.33008310e-02,  2.22448353e-02,  6.56106845e-02,
#          3.09441034e-02,  8.89721420e-03,  6.67960718e-02,
#         -9.59238503e-03, -3.72671001e-02,  1.01390421e-01,
#         -5.71304075e-02, -5.11606298e-02,  7.31157586e-02,
#          1.05819069e-01,  1.71794146e-02, -3.78164649e-02,
#          5.84836118e-02,  2.03296300e-02,  1.85886174e-02,
#          1.19359933e-01,  4.40377668e-02,  7.96061307e-02,
#          5.35288192e-02,  5.72574735e-02, -2.18866225e-02,
#         -1.47116147e-02, -6.35983124e-02, -2.07957011e-02,
#         -2.79416535e-02, -5.37681654e-02,  6.63992111e-03,
#         -1.20264255e-01,  4.51834053e-02, -5.22641093e-02,
#         -8.81028697e-02,  1.31241187e-01, -9.02343169e-02,
#          5.15329391e-02, -3.57263051e-02, -1.09712593e-02,
#          8.44019875e-02, -7.58266449e-02, -5.47694974e-03,
#         -8.44060853e-02,  1.42992204e-02, -6.79326728e-02,
#         -3.34188296e-03,  6.64470121e-02, -1.45427147e-02,
#          3.53661813e-02, -7.60531649e-02, -6.14182577e-02,
#         -1.36608765e-01,  3.71733215e-04, -7.36251697e-02,
#          1.45685794e-02,  7.29780365e-03,  2.51218807e-02,
#          2.58767586e-02, -2.34098695e-02,  5.94321825e-02,
#         -2.50274669e-02,  1.41519651e-01, -1.85713749e-02,
#          1.96336936e-02,  2.27136053e-02, -5.43300137e-02,
#         -4.14138101e-02, -4.68819439e-02, -2.71415222e-04,
#         -1.97982006e-02,  3.44139598e-02, -1.74967442e-02,
#          1.03737526e-01, -6.03439286e-02,  8.89166147e-02,
#          1.41228950e-02,  2.61243228e-02, -2.03744378e-02,
#          1.73846949e-02, -8.08983669e-02, -4.81458008e-02,
#         -4.34273258e-02, -3.36171053e-02,  1.26266270e-03,
#          1.73229724e-02, -1.75087489e-02,  9.29292813e-02,
#          8.13523158e-02, -4.70819399e-02, -1.32104501e-01,
#         -2.16585081e-02, -1.02161534e-01,  1.77484006e-02,
#          4.80684936e-02, -3.85408029e-02, -5.08420728e-02,
#         -3.60248685e-02, -8.45291018e-02, -2.67371349e-02,
#          3.16164969e-03,  1.98211651e-02, -7.12268725e-02,
#         -3.34398709e-02,  4.83278893e-02,  8.75058770e-03,
#         -2.87745930e-02, -2.89589148e-02,  4.35854942e-02,
#          6.95862472e-02, -4.28979583e-02,  5.36556169e-02,
#          5.29619791e-02, -3.44061367e-02, -2.29777601e-02,
#         -1.81654040e-02, -7.82373082e-03, -4.76653725e-02,
#          1.77320074e-02,  4.25333418e-02,  3.94249074e-02,
#          2.06544567e-02, -2.51260474e-02, -3.85190956e-02,
#          9.60688293e-02, -7.13452473e-02, -2.25799400e-02,
#          3.92376445e-02, -3.21650431e-02, -1.09457754e-01,
#          5.59774749e-02, -6.06509129e-05,  6.74058273e-02,
#         -1.18084453e-01, -1.43244117e-02,  4.56924997e-02,
#         -1.15695468e-03, -9.78593826e-02, -1.78586729e-02,
#          5.75337373e-03,  5.93435541e-02,  3.55086178e-02,
#          4.05959971e-02, -5.83093278e-02,  1.74303688e-02,
#          4.93791401e-02,  6.70227502e-03, -8.36994797e-02,
#         -1.00673707e-02,  1.85736697e-02, -2.63085645e-02,
#         -7.55305439e-02,  7.34095573e-02, -9.61319953e-02,
#          4.64644581e-02, -1.45979291e-02, -5.56120947e-02,
#         -1.96549427e-02, -2.80197226e-02, -2.52640806e-02,
#         -5.05219363e-02, -2.22785827e-02,  1.45849483e-02,
#         -2.79122777e-02, -1.21177502e-01,  2.13027541e-02,
#          5.43622151e-02,  8.78343508e-02, -3.90045233e-02,
#         -2.61384360e-02, -5.70135750e-03, -8.88253823e-02,
#         -2.41152407e-03, -1.08700737e-01, -4.40351702e-02,
#          4.40921783e-02,  2.91150343e-02,  2.29257829e-02,
#         -4.70661698e-03, -2.38143039e-04, -3.31649445e-02,
#         -5.79268076e-02, -1.18141830e-01, -5.40466830e-02,
#          1.24744512e-02,  2.02952381e-02, -5.14693037e-02,
#          6.13361225e-02, -8.44840333e-02, -1.32777449e-02,
#         -1.09780789e-03,  1.38741666e-02,  9.69695002e-02,
#         -5.17406166e-02,  2.95292716e-02,  8.40139911e-02,
#         -6.03291206e-03,  4.77822535e-02, -6.94762766e-02,
#         -6.66590407e-02, -9.29859430e-02,  5.55696413e-02,
#         -1.30968496e-01,  5.97632630e-03, -3.72671895e-02,
#          6.09637164e-02, -8.82116482e-02,  7.12275086e-03,
#          6.39887601e-02,  2.89096348e-02,  2.65720114e-02,
#          9.17458627e-03, -9.31066945e-02,  1.80585235e-02,
#          8.43367651e-02,  4.41315882e-02,  2.75616329e-02,
#         -6.77861497e-02, -1.32390648e-01, -1.56619158e-02,
#         -9.08542797e-02,  4.64384556e-02,  9.68908444e-02,
#         -8.09811875e-02,  5.69853093e-03, -1.00079723e-01,
#          5.99635094e-02,  7.14971963e-03,  2.18826961e-02,
#          1.01876184e-02,  8.75667557e-02,  1.50269596e-02,
#          2.76388228e-02,  1.11046441e-01, -3.71594890e-03,
#         -3.75079885e-02, -9.66881867e-03, -1.04021236e-01,
#         -4.22635227e-02, -3.64010148e-02,  4.82773073e-02,
#          3.75469811e-02,  7.39953965e-02,  1.91129558e-02,
#          5.77847995e-02, -1.20500233e-02, -3.72183733e-02,
#         -9.97964293e-02, -9.20016617e-02, -1.03320524e-01,
#          9.89209414e-02, -6.48464039e-02,  6.72318861e-02,
#         -1.30981877e-01, -9.79955588e-03,  1.98480254e-03,
#          1.37615874e-02,  8.87656137e-02,  5.41911870e-02,
#          1.70287509e-02,  2.88440660e-03,  8.92189667e-02,
#         -2.00550444e-02,  6.48006890e-03,  3.16987857e-02,
#          8.29093717e-03, -6.54253215e-02,  5.79049550e-02],
#        [-4.66639847e-02, -1.22988410e-02,  2.36650482e-02,
#         -2.03293655e-02,  7.51723573e-02,  4.36581001e-02,
#         -6.30267262e-02,  3.79524603e-02, -4.88352589e-02,
#         -8.04384723e-02, -9.53100920e-02, -8.90531391e-02,
#          6.93975165e-02,  1.50515968e-02, -1.02440147e-02,
#         -1.51065402e-02,  3.97454947e-02,  6.61553815e-02,
#          3.41063999e-02, -4.48974930e-02,  1.00032747e-01,
#          2.41917442e-03, -2.33838096e-01, -5.66537566e-02,
#          3.32906609e-04, -7.80168548e-02,  7.07451701e-02,
#         -3.93184163e-02,  4.76229712e-02, -2.52481773e-02,
#         -1.97782777e-02,  2.85503734e-03,  1.00114107e-01,
#         -6.61030561e-02,  6.19786605e-02,  2.38034707e-02,
#         -1.77482571e-02, -2.08504330e-02, -5.84183447e-02,
#         -6.69324920e-02,  8.44644755e-02,  7.89429098e-02,
#          5.20055369e-02, -6.88194903e-03,  8.28854144e-02,
#         -4.40778285e-02,  1.08975712e-02, -2.69110780e-02,
#          7.83168972e-02, -6.85494170e-02,  4.97852042e-02,
#          6.52741641e-02,  1.11671567e-01,  1.71791483e-02,
#          6.53506666e-02, -6.55070245e-02, -5.47591299e-02,
#         -2.38986965e-02,  2.38413294e-03,  5.24147898e-02,
#         -7.00541660e-02,  5.61110713e-02,  9.50850323e-02,
#          1.03735663e-02,  1.70016978e-02,  2.27185935e-02,
#         -7.43917972e-02,  2.56831199e-02,  1.15983829e-01,
#          8.47982150e-03,  5.82822151e-02,  7.32998550e-02,
#         -1.02542683e-01, -4.09646258e-02,  2.95408200e-02,
#          2.94096936e-02, -2.20361017e-02,  3.24929580e-02,
#         -9.31732059e-02, -8.89155641e-02, -2.58195456e-02,
#         -1.30501864e-02, -1.10796597e-02, -5.03760204e-02,
#          5.12166284e-02, -1.90769173e-02, -5.83798215e-02,
#          4.47923318e-02,  3.31466049e-02, -2.95813195e-02,
#         -4.57704142e-02, -1.32159814e-01,  7.54187815e-03,
#         -6.26429021e-02, -2.55425833e-03,  2.45709866e-02,
#          1.47302449e-02,  3.85502018e-02, -5.20072244e-02,
#         -2.94465404e-02, -3.59726301e-03,  1.25455866e-02,
#          1.95129905e-02, -2.54603624e-02, -5.97129352e-02,
#          3.21443081e-02,  1.59345660e-02, -6.01841137e-02,
#         -3.48508777e-03,  6.04012758e-02,  5.59869297e-02,
#          1.46924064e-03, -9.05977264e-02, -3.25262062e-02,
#         -1.54686496e-02,  6.75523002e-03,  9.90727916e-02,
#          7.19664842e-02,  3.65496352e-02,  4.16563153e-02,
#         -2.39758845e-02, -6.44396171e-02,  4.57829908e-02,
#         -9.76848509e-03, -4.62741591e-02,  9.19719040e-03,
#          4.09176759e-02,  6.67387918e-02,  1.88405160e-02,
#          3.02663054e-02,  1.23778576e-04, -6.81397691e-02,
#          3.71101759e-02,  1.24332672e-02, -6.59965426e-02,
#         -1.47963380e-02, -4.82834168e-02, -8.08784664e-02,
#          3.61603089e-02, -1.16840852e-02,  8.42055455e-02,
#          3.77931595e-02, -2.33689807e-02,  1.11192860e-01,
#         -4.91065122e-02, -8.96640774e-03, -5.41991107e-02,
#          2.78330911e-02,  8.24845880e-02, -1.02149606e-01,
#          1.18892537e-02,  2.95084752e-02, -1.84422042e-02,
#         -9.88702998e-02, -4.64285426e-02,  3.80923785e-03,
#          2.46236585e-02, -8.84839073e-02, -1.36306202e-02,
#          1.34128937e-02,  2.52855569e-02, -1.07247278e-01,
#         -1.17792159e-01,  3.03019062e-02,  1.26769897e-02,
#         -7.28706568e-02,  3.08415741e-02,  1.99613757e-02,
#         -2.61862036e-02, -4.17679138e-02,  3.38347852e-02,
#         -4.16842662e-02,  3.88179943e-02, -1.53900748e-02,
#          7.85654485e-02, -3.79941165e-02,  7.43297976e-04,
#          5.76047488e-02, -7.52065927e-02, -1.09526366e-02,
#         -3.06108035e-02, -2.69733015e-02, -1.45407170e-02,
#         -5.56811737e-03, -2.47531421e-02,  2.03447603e-03,
#         -4.70152050e-02, -5.40890880e-02, -1.86559986e-02,
#         -2.14453060e-02, -3.46792676e-02,  1.36571713e-02,
#         -7.16642886e-02, -1.14568102e-03,  3.51798604e-03,
#         -6.26248419e-02,  9.75293573e-03, -5.54044507e-02,
#          4.87039126e-02, -1.09454259e-01, -8.02200171e-04,
#          1.98621303e-03,  5.27348928e-02,  3.39387543e-02,
#         -3.28002833e-02, -5.83029203e-02,  2.33713887e-03,
#         -5.71168885e-02, -2.53775492e-02,  2.54137646e-02,
#          8.80712084e-03,  1.05598876e-02,  3.50785516e-02,
#          8.57488159e-03, -6.16093203e-02,  3.65355946e-02,
#          1.84597187e-02,  1.42546579e-01, -4.89505157e-02,
#          7.92719573e-02, -3.38190757e-02,  6.27774894e-02,
#          6.90191835e-02, -2.75047813e-02,  5.55077493e-02,
#         -9.67457369e-02, -1.29248753e-01,  1.93429410e-01,
#         -1.10549992e-02, -5.33256643e-02, -9.16129872e-02,
#         -2.34447001e-03,  1.79668628e-02,  8.64426494e-02,
#         -1.57465458e-01,  3.99984308e-02, -2.14224737e-02,
#         -3.86631601e-02, -8.54870155e-02, -1.11870050e-01,
#          4.40455750e-02,  1.22079216e-01,  1.36496425e-02,
#         -4.71815765e-02, -3.01729944e-02,  3.52493264e-02,
#          2.98885647e-02,  1.36966223e-03, -6.81740344e-02,
#          4.44279313e-02, -5.21578230e-02, -2.28623245e-02,
#          3.46945859e-02, -7.67472312e-02,  5.55192307e-02,
#         -8.03170539e-03,  2.52069999e-02, -8.71798545e-02,
#          4.58751768e-02,  1.00214392e-01, -4.18279693e-02,
#         -1.06738977e-01, -2.35519204e-02,  7.96226636e-02,
#          2.19328236e-02, -4.54589315e-02, -5.11484258e-02,
#         -1.02698378e-01, -9.23870504e-02,  4.92506400e-02,
#         -2.98484415e-02,  1.43483542e-02,  3.09897158e-02,
#         -3.50459255e-02,  2.22091544e-02,  1.27153872e-02,
#          4.28449027e-02, -4.61894162e-02, -7.36443475e-02,
#          6.58506854e-03, -7.78176710e-02,  8.52794666e-03,
#          4.01381664e-02,  5.52721554e-03,  2.80875806e-02,
#          3.27659436e-02, -9.66788232e-02, -6.52010813e-02,
#         -5.73362485e-02, -3.54340896e-02, -3.73953208e-03,
#         -2.62733139e-02,  9.01580229e-02, -1.75632853e-02,
#         -4.95412014e-02, -1.83753863e-01,  5.37704676e-02,
#          5.06510027e-02,  7.03890109e-03,  4.02591228e-02]], dtype=float32)
