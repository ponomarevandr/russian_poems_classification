# %% [markdown]
# # Разметка датасета русских классических стихов

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_poems = pd.read_csv('../data/poems_prepared.csv')
df_poems
# Out:
#          author                         title  part  \
# 0      Агнивцев                  брат антонио     0
# 1      Агнивцев                 грузовик 1317     0
# 2      Агнивцев                 грузовик 1317     1
# 3      Агнивцев                  мэри пикфорд     0
# 4      Агнивцев                      бильбокэ     0
# ...         ...                           ...   ...
# 54232      Яшин                     зеркальце     2
# 54233      Яшин  очень много солнечного света     0
# 54234      Яшин                        огонек     0
# 54235      Яшин    назови меня именем светлым     0
# 54236      Яшин                   твоя родина     0
#
#                                                     text
# 0      В монастырской тихой келье,\nПозабывши о весел...
# 1      Весь машинный свой век, каждый день по утрам\n...
# 2      Грузовик № 1317.\nНо открылись фронты! О, услы...
# 3      В Америке где-то\nСудя по газетам,\nЕсть город...
# 4      К дофину Франции, в печали,\nСкользнув тайком,...
# ...                                                  ...
# 54232  В руки зеркальце взяла\nИ сказала:\n«Удружи,\n...
# 54233  Очень много солнечного света,\nНад землей стои...
# 54234  Светлячок во мгле —\nОгонек в лесах.\nМожет, о...
# 54235  Назови меня именем светлым,\nЧистым именем наз...
# 54236  Все испытала, все превозмогла —\nГода тяжелых ...
#
# [54237 rows x 4 columns]

# %% [markdown]
# Каждому стихотворному фрагменту присваивается метка эпохи (течения, направления) в поэзии. Эпоха определяется по принадлежности к ней автора фрагмента.

# %%
authors = df_poems['author'].unique()
authors
# Out:
# array(['Агнивцев', 'Алигер', 'Анненский', 'Антокольский', 'Анчаров',
#        'Апухтин', 'Асадов', 'Асеев', 'Ахмадулина', 'Ахматова',
#        'Багрицкий-отец', 'Багрицкий-сын', 'Балтрушайтис', 'Бальмонт',
#        'Баратынский', 'Барто', 'Батюшков', 'Бедный', 'Белый', 'Берггольц',
#        'Бестужев', 'Блок', 'Боков', 'Бродский', 'Брюсов', 'Бунин',
#        'Ваншенкин', 'Введенский', 'Веневитинов', 'Винокуров',
#        'Вознесенский', 'Волошин', 'Высоцкий', 'Вяземский', 'Габриак',
#        'Галина', 'Гамзатов', 'Герасимов', 'Герцык', 'Гиппиус', 'Глазков',
#        'Глинка', 'Гончаров', 'Городецкий', 'Горький', 'Грибоедов',
#        'Григорьев', 'Гудзенко', 'Гумилев', 'Гуро', 'Давыдов', 'Дельвиг',
#        'Дементьев', 'Державин', 'Долматовский', 'Друнина', 'Дудин',
#        'Евтушенко', 'Есенин', 'Жемчужников', 'Жигулин', 'Жуковский',
#        'Заболоцкий', 'Зенкевич', 'Иванов-В', 'Иванов-Г', 'Ивнев', 'Инбер',
#        'Исаковский', 'Казакова', 'Казин', 'Капнист', 'Карамзин',
#        'Катенин', 'Кедрин', 'Кирсанов', 'Клычков', 'Клюев', 'Коган',
#        'Козлов', 'Кольцов', 'Коржавин', 'Кочетков', 'Кривин', 'Крученых',
#        'Крылов', 'Кузмин', 'Кульчицкий', 'Кушнер', 'Кюхельбекер',
#        'Лебедев-Кумач', 'Левитанский', 'Лермонтов', 'Ломоносов',
#        'Лохвицкая', 'Луговской', 'Майков', 'Мандельштам', 'Мартынов',
#        'Маршак', 'Матвеева', 'Маяковский', 'Межиров', 'Мей',
#        'Мережковский', 'Михалков', 'Мориц', 'Мятлев', 'Набоков', 'Надсон',
#        'Нарбут', 'Наровчатов', 'Некрасов', 'Никитин', 'Обрадович',
#        'Огарев', 'Одоевский', 'Одоевцева', 'Озеров', 'Ознобишин',
#        'Окуджава', 'Олейников', 'Орлов', 'Отрада', 'Ошанин', 'Павлова',
#        'Парнок', 'Пастернак', 'Петровых', 'Плещеев', 'Поделков',
#        'Полежаев', 'Полонский', 'Поплавский', 'Прутков', 'Пушкин',
#        'Радищев', 'Раевский', 'Рерих', 'Рождественский-В',
#        'Рождественский-Р', 'Романов', 'Ростопчина', 'Рубцов', 'Рылеев',
#        'Самойлов', 'Светлов', 'Северянин', 'Сельвинский', 'Симонов',
#        'Слуцкий', 'Случевский', 'Смеляков', 'Смоленский', 'Соловьев',
#        'Сологуб', 'Солоухин', 'Сумароков', 'Суриков', 'Сурков', 'Сухарев',
#        'Тарковский', 'Твардовский', 'Тихонов', 'Толстой', 'Тредиаковский',
#        'Тургенев', 'Тушнова', 'Тэффи', 'Тютчев', 'Уткин', 'Федоров',
#        'Фет', 'Фофанов', 'Хармс', 'Хлебников', 'Ходасевич', 'Цветаева',
#        'Черный', 'Чичибабин', 'Чуковский', 'Шаламов', 'Шершеневич',
#        'Шефнер', 'Шпаликов', 'Щипачев', 'Эренбург', 'Языков', 'Яшин'],
#       dtype=object)

# %%
# Классицизм
# XVIII век
authors_classicism = [
    'Державин',
    'Капнист',
    'Карамзин',
    'Ломоносов',
    'Радищев',
    'Сумароков',
    'Тредиаковский'
]

# %%
# Золотой век русской поэзии (близко к понятию романтизма)
# первая половина XIX века
authors_golden_age = [
    'Баратынский',
    'Батюшков',
    'Бестужев',
    'Веневитинов',
    'Вяземский',
    'Глинка',
    'Давыдов',
    'Дельвиг',
    'Жуковский',
    'Катенин',
    'Козлов',
    'Кольцов',
    'Кюхельбекер',
    'Лермонтов',
    'Мей',
    'Мятлев',
    'Одоевский',
    'Ознобишин',
    'Пушкин',
    'Раевский',
    'Ростопчина',
    'Рылеев',
    'Тютчев',
    'Фет',
    'Языков'
]

# %%
# Критический реализм (близко к понятию "натуральная школа")
# вторая половина XIX века
authors_critical_realism = [
    'Апухтин',
    'Грибоедов',
    'Григорьев',
    'Жемчужников',
    'Крылов',
    'Майков',
    'Надсон',
    'Некрасов',
    'Никитин',
    'Огарев',
    'Павлова',
    'Плещеев',
    'Полежаев',
    'Полонский',
    'Прутков',
    'Случевский',
    'Соловьев',
    'Суриков',
    'Толстой',
    'Тургенев',
    'Тэффи',
    'Черный'
]

# %%
# Серебряный век русской поэзии (близко к понятию символизма)
# первая половина XX века
authors_silver_age = [
    'Агнивцев',
    'Анненский',
    'Ахматова',
    'Багрицкий-отец',
    'Балтрушайтис',
    'Бальмонт',
    'Белый',
    'Блок',
    'Брюсов',
    'Бунин',
    'Волошин',
    'Габриак',
    'Галина',
    'Герцык',
    'Гиппиус',
    'Городецкий',
    'Горький',
    'Гумилев',
    'Есенин',
    'Зенкевич',
    'Иванов-В',
    'Иванов-Г',
    'Ивнев',
    'Клычков',
    'Клюев',
    'Кузмин',
    'Лохвицкая',
    'Мандельштам',
    'Мережковский',
    'Нарбут',
    'Одоевцева',
    'Парнок',
    'Пастернак',
    'Поплавский',
    'Рерих',
    'Рождественский-В',
    'Романов',
    'Сологуб',
    'Тарковский',
    'Фофанов',
    'Ходасевич',
    'Цветаева',
    'Шершеневич'
]

# %%
# Футуризм
# первая половина XX века
authors_futurism = [
    'Асеев',
    'Введенский',
    'Гуро',
    'Крученых',
    'Мартынов',
    'Маяковский',
    'Северянин',
    'Сельвинский',
    'Хармс',
    'Хлебников'
]

# %%
# Социалистический реализм
# середина XX века
authors_soviet_realism = [
    'Алигер',
    'Антокольский',
    'Асадов',
    'Багрицкий-сын',
    'Барто',
    'Бедный',
    'Берггольц',
    'Боков',
    'Ваншенкин',
    'Винокуров',
    'Гамзатов',
    'Герасимов',
    'Гончаров',
    'Гудзенко',
    'Долматовский',
    'Друнина',
    'Дудин',
    'Жигулин',
    'Заболоцкий',
    'Инбер',
    'Исаковский',
    'Казакова',
    'Казин',
    'Кедрин',
    'Кирсанов',
    'Коган',
    'Кочетков',
    'Кульчицкий',
    'Лебедев-Кумач',
    'Луговской',
    'Маршак',
    'Межиров',
    'Михалков',
    'Мориц',
    'Наровчатов',
    'Обрадович',
    'Озеров',
    'Олейников',
    'Орлов',
    'Отрада',
    'Ошанин',
    'Петровых',
    'Поделков',
    'Самойлов',
    'Светлов',
    'Симонов',
    'Слуцкий',
    'Смоленский',
    'Сурков',
    'Твардовский',
    'Тихонов',
    'Тушнова',
    'Уткин',
    'Федоров',
    'Чуковский',
    'Шефнер',
    'Щипачев',
    'Эренбург',
    'Яшин'
]

# %%
# Поэзия шестидесятников
# Вторая половина XX века
authors_sixtiers = [
    'Анчаров',
    'Ахмадулина',
    'Бродский',
    'Вознесенский',
    'Высоцкий',
    'Глазков',
    'Дементьев',
    'Евтушенко',
    'Коржавин',
    'Кривин',
    'Кушнер',
    'Левитанский',
    'Набоков',
    'Матвеева',
    'Окуджава',
    'Рождественский-Р',
    'Рубцов',
    'Смеляков',
    'Солоухин',
    'Сухарев',
    'Чичибабин',
    'Шаламов',
    'Шпаликов'
]

# %%
authors_with_movements = \
    authors_classicism + \
    authors_golden_age + \
    authors_critical_realism + \
    authors_silver_age + \
    authors_futurism + \
    authors_soviet_realism + \
    authors_sixtiers

# %%
df_authors = pd.DataFrame(columns=['name', 'epoch'])
df_authors['name'] = authors
df_authors = df_authors.set_index('name')

# %%
df_authors.loc[authors_classicism, 'epoch'] = 'классицизм'
df_authors.loc[authors_golden_age, 'epoch'] = 'золотой век'
df_authors.loc[authors_critical_realism, 'epoch'] = 'критический реализм'
df_authors.loc[authors_silver_age, 'epoch'] = 'серебряный век'
df_authors.loc[authors_futurism, 'epoch'] = 'футуризм'
df_authors.loc[authors_soviet_realism, 'epoch'] = 'соцреализм'
df_authors.loc[authors_sixtiers, 'epoch'] = 'шестидесятники'

# %%
df_authors
# Out:
#                        epoch
# name
# Агнивцев      серебряный век
# Алигер            соцреализм
# Анненский     серебряный век
# Антокольский      соцреализм
# Анчаров       шестидесятники
# ...                      ...
# Шпаликов      шестидесятники
# Щипачев           соцреализм
# Эренбург          соцреализм
# Языков           золотой век
# Яшин              соцреализм
#
# [189 rows x 1 columns]

# %%
df_poems = df_poems.drop('epoch', axis=1, errors='ignore')
df_poems.insert(1, 'epoch', df_authors.loc[df_poems['author']].reset_index()['epoch'])
df_poems
# Out:
#          author           epoch                         title  part  \
# 0      Агнивцев  серебряный век                  брат антонио     0
# 1      Агнивцев  серебряный век                 грузовик 1317     0
# 2      Агнивцев  серебряный век                 грузовик 1317     1
# 3      Агнивцев  серебряный век                  мэри пикфорд     0
# 4      Агнивцев  серебряный век                      бильбокэ     0
# ...         ...             ...                           ...   ...
# 54232      Яшин      соцреализм                     зеркальце     2
# 54233      Яшин      соцреализм  очень много солнечного света     0
# 54234      Яшин      соцреализм                        огонек     0
# 54235      Яшин      соцреализм    назови меня именем светлым     0
# 54236      Яшин      соцреализм                   твоя родина     0
#
#                                                     text
# 0      В монастырской тихой келье,\nПозабывши о весел...
# 1      Весь машинный свой век, каждый день по утрам\n...
# 2      Грузовик № 1317.\nНо открылись фронты! О, услы...
# 3      В Америке где-то\nСудя по газетам,\nЕсть город...
# 4      К дофину Франции, в печали,\nСкользнув тайком,...
# ...                                                  ...
# 54232  В руки зеркальце взяла\nИ сказала:\n«Удружи,\n...
# 54233  Очень много солнечного света,\nНад землей стои...
# 54234  Светлячок во мгле —\nОгонек в лесах.\nМожет, о...
# 54235  Назови меня именем светлым,\nЧистым именем наз...
# 54236  Все испытала, все превозмогла —\nГода тяжелых ...
#
# [54237 rows x 5 columns]

# %% [markdown]
# ## Статистика по течениям

# %%
df_poems.groupby('epoch').size()
# Out:
# epoch
# золотой век             8561
# классицизм              3281
# критический реализм     9428
# серебряный век         16204
# соцреализм              5883
# футуризм                7642
# шестидесятники          3238
# dtype: int64

# %% [markdown]
# ## Сохряняем

# %%
df_poems.to_csv('../data/poems_dataset.csv', index=False)
